# %% [markdown]
# ## Actividad práctica

# %%
from libreria.estadistica_basica import media, mediana, moda

datos = [10, 8, 10, 7, 9, 10, 8]

print("Media:", media(datos))
print("Mediana:", mediana(datos))
print("Moda:", moda(datos))
# Out:
# Media: 8.857142857142858
# Mediana: 9.0
# Moda: 10

# %%
help(media)
# Out:
# Help on function media in module libreria.estadistica_basica:
#
# media(valores: Iterable[Union[int, float]]) -> float
#     Calcula la media aritmética.
#
#     Parámetros
#     ----------
#     valores : Iterable[Numero]
#         Secuencia de números (no vacía).
#
#     Retorna
#     -------
#     float
#         Promedio de los valores.

# %%
help(moda)
# Out:
# Help on function moda in module libreria.estadistica_basica:
#
# moda(valores: Iterable[Union[int, float]]) -> Union[int, float]
#     Calcula la moda (valor más frecuente).
#
#     Si hay empate, retorna cualquiera de las modas.

# %%
help(mediana)
# Out:
# Help on function mediana in module libreria.estadistica_basica:
#
# mediana(valores: Iterable[Union[int, float]]) -> float
#     Calcula la mediana (valor central).
#
#     Si hay cantidad par, retorna el promedio de los dos centrales.
